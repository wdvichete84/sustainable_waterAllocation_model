# %% [markdown]
# # 1. Import Libraies
# First import the libaries need it to run the model.

# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
from pywr.notebook import draw_graph
import pandas
import numpy as np
import pywr

# %% [markdown]
# # 2. Run the model and show recorders to check the results
# After to conclude the Json file, it's possible run the model from the code bellow.
#
# set the model to "m"

# %%
if __name__ == "__main__":

    m = Model.load("C:/workspace/pywr/Hydrossustainable_wAllocation/B_hydroecon_wtransfer/B_hydroecon_wtransfer1_1_mrf.json")
    stats = m.run()
    print(stats)

    print(m)
    print("nodes:", len(m.nodes))
    draw_graph(m)
   
    print(m.recorders["sobradinho_energy"].values())

    df = m.to_dataframe()
    print(df.head())

    from matplotlib import pyplot as plt

    df.plot(subplots=True)
    plt.show()
# Out:
# Model executed 1 scenarios in 12.7 seconds, running at 88.9 timesteps per second.
# <pywr._model.Model object at 0x00000186F30EA590>
# nodes: 92
# <MemoryView of 'ndarray' object>
# Recorder  xingo_energy pafonso_energy itaparica_energy sobrad_storage  \
#                      0              0                0              0
# 1941-01   2.766260e+08   3.450731e+08     9.372147e+07   3.411600e+10
# 1941-02   2.754799e+08   3.909955e+08     9.775921e+07   3.411600e+10
# 1941-03   2.754030e+08   3.908918e+08     9.775355e+07   3.411600e+10
# 1941-04   2.754708e+08   3.909861e+08     9.775858e+07   3.411600e+10
# 1941-05   2.753151e+08   3.907694e+08     9.774680e+07   3.325451e+10
#
# Recorder sobradinho_flow_ener itaparica_flow_ener pafonso_flow_ener  \
#                             0                   0                 0
# 1941-01           369000000.0         237900000.0       309052800.0
# 1941-02           369000000.0         237900000.0       362880000.0
# 1941-03           369000000.0         237900000.0       362880000.0
# 1941-04           369000000.0         237900000.0       362880000.0
# 1941-05           369000000.0         237900000.0       362880000.0
#
# Recorder xingo_flow_ener sobradinho_energy sobradinho_new_level_value
#                        0                 0                          0
# 1941-01      259200000.0      7.610547e+07                  23.360277
# 1941-02      260000000.0      6.220145e+07                  19.092492
# 1941-03      260000000.0      6.221407e+07                  19.096366
# 1941-04      260000000.0      6.229589e+07                  19.121479
# 1941-05      260000000.0      6.211064e+07                  19.064619
