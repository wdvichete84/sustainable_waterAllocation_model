# %% [markdown]
# # 1. Import Libraies
# First import the libaries need it to run the model.

# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
from pywr.notebook import draw_graph
import pandas
import numpy as np
import pywr

# %% [markdown]
# # 2. Run the model and show recorders to check the results
# After to conclude the Json file, it's possible run the model from the code bellow.
#
# set the model to "m"

# %%
if __name__ == "__main__":

    m = Model.load("C:/workspace/pywr/Hydrossustainable_wAllocation/A_priorityBased_wtransfer/A_priorityBased_wtransfer3.json")
    stats = m.run()
    print(stats)

    print(m)
    print("nodes:", len(m.nodes))
    draw_graph(m)
   
    print(m.recorders["sobradinho_energy"].values())

    df = m.to_dataframe()
    print(df.head())

    from matplotlib import pyplot as plt

    df.plot(subplots=True)
    plt.show()
# Out:
# Model executed 1 scenarios in 3.1 seconds, running at 320.4 timesteps per second.
# <pywr._model.Model object at 0x0000015298B66AA0>
# nodes: 63
# <MemoryView of 'ndarray' object>
# Recorder  xingo_energy pafonso_energy itaparica_energy sobrad_storage  \
#                      0              0                0              0
# 1941-01   2.766260e+08   3.450731e+08     9.372147e+07   7.475440e+09
# 1941-02   2.751468e+08   3.311441e+08     8.802329e+07   5.447000e+09
# 1941-03   2.752725e+08   3.313427e+08     8.803235e+07   5.447000e+09
# 1941-04   2.754748e+08   3.315840e+08     8.804796e+07   5.447000e+09
# 1941-05   2.753093e+08   3.313885e+08     8.803552e+07   5.447000e+09
#
# Recorder sobradinho_flow_ener itaparica_flow_ener pafonso_flow_ener  \
#                             0                   0                 0
# 1941-01           368000000.0         237900000.0       309052800.0
# 1941-02           368000000.0         236908000.0       309052800.0
# 1941-03           368000000.0         236908000.0       309052800.0
# 1941-04           368000000.0         236908000.0       309052800.0
# 1941-05           368000000.0         236908000.0       309052800.0
#
# Recorder xingo_flow_ener sobradinho_energy sobradinho_new_level_value
#                        0                 0                          0
# 1941-01      259200000.0      6.847236e+07                  21.074435
# 1941-02      260000000.0      2.565065e+07                   7.894763
# 1941-03      260000000.0      2.240451e+07                   6.895664
# 1941-04      260000000.0      2.267344e+07                   6.978436
# 1941-05      260000000.0      2.247561e+07                   6.917548
