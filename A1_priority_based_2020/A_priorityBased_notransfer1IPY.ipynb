# %% [markdown]
# # 1. Import Libraies
# First import the libaries need it to run the model.

# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
from pywr.notebook import draw_graph
import pandas
import numpy as np
import pywr

# %% [markdown]
# # 2. Run the model and show recorders to check the results
# After to conclude the Json file, it's possible run the model from the code bellow.
#
# set the model to "m"

# %%
if __name__ == "__main__":

    m = Model.load("C:/workspace/pywr/Hydrossustainable_wAllocation/A_priorityBased_notransfer/A_priorityBased_notransfer1.json")
    stats = m.run()
    print(stats)

    print(m)
    print("nodes:", len(m.nodes))
    draw_graph(m)
   
    print(m.recorders["sobradinho_energy"].values())

    df = m.to_dataframe()
    print(df.head())

    from matplotlib import pyplot as plt

    df.plot(subplots=True)
    plt.show()
# Out:
# Model executed 1 scenarios in 3.9 seconds, running at 251.5 timesteps per second.
# <pywr._model.Model object at 0x000001244347C280>
# nodes: 53
# <MemoryView of 'ndarray' object>
# Recorder  xingo_energy pafonso_energy itaparica_energy sobrad_storage  \
#                      0              0                0              0
# 1941-01   2.766260e+08   3.450731e+08     9.372147e+07   7.530797e+09
# 1941-02   2.751448e+08   3.311410e+08     8.802319e+07   5.447000e+09
# 1941-03   2.752499e+08   3.313087e+08     8.803019e+07   5.447000e+09
# 1941-04   2.754500e+08   3.315550e+08     8.804634e+07   5.447000e+09
# 1941-05   2.752845e+08   3.313588e+08     8.803364e+07   5.447000e+09
#
# Recorder sobradinho_flow_ener itaparica_flow_ener pafonso_flow_ener  \
#                             0                   0                 0
# 1941-01           368000000.0         237900000.0       309052800.0
# 1941-02           368000000.0         236908000.0       309052800.0
# 1941-03           368000000.0         236908000.0       309052800.0
# 1941-04           368000000.0         236908000.0       309052800.0
# 1941-05           368000000.0         236908000.0       309052800.0
#
# Recorder xingo_flow_ener sobradinho_energy sobradinho_new_level_value
#                        0                 0                          0
# 1941-01      259200000.0      6.847236e+07                  21.074435
# 1941-02      260000000.0      2.577561e+07                   7.933221
# 1941-03      260000000.0      2.239506e+07                   6.892755
# 1941-04      260000000.0      2.266893e+07                   6.977047
# 1941-05      260000000.0      2.247110e+07                   6.916158
