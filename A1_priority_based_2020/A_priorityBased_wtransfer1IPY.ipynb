# %% [markdown]
# # 1. Import Libraies
# First import the libaries need it to run the model.

# %%
from pywr.core import Model
from pywr.recorders import Recorder
from pywr.recorders._recorders import NodeRecorder
from pywr.notebook import draw_graph
import pandas
import numpy as np
import pywr

# %% [markdown]
# # 2. Run the model and show recorders to check the results
# After to conclude the Json file, it's possible run the model from the code bellow.
#
# set the model to "m"

# %%
if __name__ == "__main__":

    m = Model.load("C:/workspace/pywr/Hydrossustainable_wAllocation/A_priorityBased_wtransfer/A_priorityBased_wtransfer1.json")
    stats = m.run()
    print(stats)

    print(m)
    print("nodes:", len(m.nodes))
    draw_graph(m)
   
    print(m.recorders["sobradinho_energy"].values())

    df = m.to_dataframe()
    print(df.head())

    from matplotlib import pyplot as plt

    df.plot(subplots=True)
    plt.show()
# Out:
# Model executed 1 scenarios in 3.8 seconds, running at 264.7 timesteps per second.
# <pywr._model.Model object at 0x000001708A66F2B0>
# nodes: 63
# <MemoryView of 'ndarray' object>
# Recorder  xingo_energy pafonso_energy itaparica_energy sobrad_storage  \
#                      0              0                0              0
# 1941-01   2.766260e+08   3.450731e+08     9.372147e+07   7.581122e+09
# 1941-02   2.751455e+08   3.311420e+08     8.802323e+07   5.447000e+09
# 1941-03   2.752501e+08   3.313107e+08     8.803039e+07   5.447000e+09
# 1941-04   2.754548e+08   3.315609e+08     8.804680e+07   5.447000e+09
# 1941-05   2.752893e+08   3.313646e+08     8.803410e+07   5.447000e+09
#
# Recorder sobradinho_flow_ener itaparica_flow_ener pafonso_flow_ener  \
#                             0                   0                 0
# 1941-01           368000000.0         237900000.0       309052800.0
# 1941-02           368000000.0         236908000.0       309052800.0
# 1941-03           368000000.0         236908000.0       309052800.0
# 1941-04           368000000.0         236908000.0       309052800.0
# 1941-05           368000000.0         236908000.0       309052800.0
#
# Recorder xingo_flow_ener sobradinho_energy sobradinho_new_level_value
#                        0                 0                          0
# 1941-01      259200000.0      6.847236e+07                  21.074435
# 1941-02      260000000.0      2.588920e+07                   7.968183
# 1941-03      260000000.0      2.238646e+07                   6.890110
# 1941-04      260000000.0      2.266482e+07                   6.975784
# 1941-05      260000000.0      2.246699e+07                   6.914895
